# %% [markdown]
# # ETL Project
#
# ## Team: ETheL
#
# ### Neil Patel, Caroline Miller, Ashley Fay

# %%
#Required imports

import pandas as pd
import numpy as np
import datetime as datetime
import json
from pandas.io.json import json_normalize

# %%
#Load first data file, Amazon

file_1 = "amazon_com.csv"
amazon = pd.read_csv(file_1)
#amazon.head(2)

# %%
#Load second data file, Amazon with extras

file_2 = "amazon_com_extras.csv"
amazon_ex = pd.read_csv(file_2, encoding = "ISO-8859-1")

#Select columns desired for usable df
amazon_ex = amazon_ex[['ASIN','GROUP','FORMAT','TITLE','AUTHOR','PUBLISHER']]

#Make column headers lowercase
amazon_ex.columns = amazon_ex.columns.str.lower()

#amazon_ex.head(2)

# %%
#Load third data file, Netflix movies

file_3 = "netflix_movie_titles.csv"

#Apply encoding and code for file errors
netflix = pd.read_csv(file_3, encoding = "ISO-8859-1", header = None, engine = 'python', error_bad_lines=False)

#Rename column names from index based
netflix.rename(columns={0:'Count',1:'Year', 2:'Movie Title'}, inplace=True)


#Drop count
netflix.drop(columns=['Count'], inplace = True)

#netflix.head(2)

# %%
#Netflix file - Remove NaN and replace with 0 in the Year column
netflix['Year'].fillna(0, inplace = True)

#Change column from float to int
netflix['Year'].astype(int).astype(str)

netflix.dtypes
# Out:
# Year           float64
# Movie Title     object
# dtype: object

# %%
#Load fourth file, Movies_Metadata

file_4 = "movies_metadata.csv"

#Apply encoding and code for file errors
movies = pd.read_csv(file_4, encoding = "ISO-8859-1", engine = 'python', error_bad_lines=False)

#movies.head()

# %%
#Drop columns from the movies file not being used
movies.drop(columns=['adult','budget','homepage','popularity','id','production_countries','imdb_id','original_language','original_title','poster_path','production_companies','belongs_to_collection','runtime','revenue','overview','spoken_languages','video','vote_count'], inplace = True)
#movies.head()

# %%
#Merge movies file and amazon books file into 1 df by title
merged_df = pd.merge(amazon_ex, movies, on='title', how = 'inner')

#Make title column the index
#merged_df = merged_df.set_index('title')

#merged_df.head(2)

# %%
#Now merge Netflix file into df 
merged_df_2 = pd.merge(merged_df, netflix, left_on='title',right_on= 'Movie Title')
#merged_df_2.head()

# %%
#Drop duplicate titles from merged_df_2, keep first
merged_df_2.drop_duplicates('title', keep = 'first', inplace=True)
merged_df_2.head(1)
# Out:
#          asin group     format title  author         publisher  \
# 0  1405246413  book  hardcover    Go   Diego   Go! Annual 2010
#
#                                               genres release_date    status  \
# 0  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...   1999-04-09  Released
#
#                                        tagline  vote_average    Year  \
# 0  A weekend wasted is never a wasted weekend.           7.0  1999.0
#
#   Movie Title
# 0          Go

# %%
#Pull out title and genres column of merged_df_2 to work with dictionaries ect within the column
#Create new smaller df to work with
genre_df = merged_df_2[['title','genres']]

#Reset the index
genre_df = genre_df.reset_index(drop=True)

genre_df.head(1)
# Out:
#   title                                             genres
# 0    Go  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...

# %%
#Create itterator that adjusts for strings by taking length of frame throught the index.
d = {'id': [], 'name': [], 'title': []}
genre_df_out = pd.DataFrame()
for index in range(len(genre_df.genres)):
    item = genre_df.genres[index]
    title = genre_df.title[index]
    #print (title)
    dataItem = json.loads(item.replace("'",'"'))
    
    df_genre = pd.DataFrame(data=dataItem)
    new_bucket = []
    tempName = ''
    genre1 = ''
    genre2 = ''
    genre3 =''
    genre4 = ''
    tempID = ''
    for index2, row in df_genre.iterrows():
        #print(row["id"],row["name"],title)
        #name = name + row["name"]
        tempName = tempName + str(row["name"]) + ','
        tempID = tempID + str(row["id"]) + ','
        if(index2 == 0):genre1 = row["name"]
        if(index2 == 1):genre2 = row["name"]
        if(index2 == 2):genre3 = row["name"]
        if(index2 == 3):genre4 = row["name"]
    
    
    new_bucket.append({'id': tempID, 'genre1': genre1,'genre2': genre2,'genre3': genre3,'genre4': genre4, 'title': title})
    genre_df_out = genre_df_out.append(new_bucket)
    
    #print(genre_df_out)

# %%
#Show final output of original genre column
genre_df_out.head(3)
# Out:
#    genre1  genre2    genre3    genre4                  id   title
# 0   Crime  Comedy  Thriller                     80,35,53,      Go
# 0   Crime   Drama    Action  Thriller        80,18,28,53,  Faster
# 0  Comedy   Drama   Romance     Music  35,18,10749,10402,    Girl

# %%
#Merge output back with main df (merged_df_2)
final_df = pd.merge(merged_df_2, genre_df_out, on='title', how = 'inner')
#Drop Duplicates
final_df.drop_duplicates('title', keep = 'first', inplace = True)
#Drop initial genres column
final_df.drop(columns=['genres'], inplace = True)
#Rename title to book title
final_df = final_df.rename(columns = {'title': 'book title'})
#Set all columns to lowercase
final_df.columns = final_df.columns.str.lower()

#Reset Index
final_df = final_df.reset_index(drop=True)
final_df
# Out:
#            asin group     format                book title  \
# 0    1405246413  book  hardcover                        Go
# 1    1498756301  book  hardcover                    Faster
# 2    1477117350  book  paperback                      Girl
# 3     316199990  book  hardcover         Are We There Yet?
# 4     816680566  book  hardcover                    Frozen
# 5      62194976  book  hardcover                 Forbidden
# 6    144240907X  book  hardcover                     Fever
# 7     374378487  book  hardcover          Tuck Everlasting
# 8    1250044669  book  hardcover                 Renegades
# 9    1484722264  book  hardcover                  Zero Day
# 10    765302519  book  hardcover                 Flashback
# 11   1576878392  book  hardcover                       Ali
# 12   9888341286  book  hardcover            Romeo & Juliet
# 13   1681195364  book  hardcover                  Breakout
# 14   1509812709  book  hardcover             The Collector
# 15    778330737  book  hardcover              The Crossing
# 16     61124958  book  hardcover           Charlotte's Web
# 17    375500200  book  hardcover                     Women
# 18   3651000001  book  hardcover                    Switch
# 19   B000YXTA18  book  hardcover                   Monster
# 20   1328879941  book  hardcover       The Handmaid's Tale
# 21   1473676355  book  hardcover              The Outsider
# 22   386647475X  book  hardcover             Anna Karenina
# 23   1328869334  book  hardcover                      1984
# 24    393068617  book  hardcover                      Jazz
# 25    670819549  book  hardcover             Little Odessa
# 26   9350296209  book  hardcover                 Dark Star
# 27    385424736  book  hardcover             The Rainmaker
# 28    385416342  book  hardcover                  The Firm
# 29   1445477963  book  hardcover       The Gingerbread Man
# ..          ...   ...        ...                       ...
# 415   312427565  book  paperback           The Right Stuff
# 416    99908409  book  paperback   The Old Man and the Sea
# 439                                   Robert K. Massie
# 440                                     Barry Connolly
# 441                          Michael Joseph Bacotti Sr
# 442                                      Jonathan Harr
# 443                                     Helen Fielding
# 444                                   James M. Jackson
#
#                                              publisher release_date    status  \
# 0                                      Go! Annual 2010   1999-04-09  Released
# 1     Cheaper in the History of Manufacturing: From...   2010-11-23  Released
# 2                                       : So They Said   1998-11-05  Released
# 3                Little, Brown Books for Young Readers   2005-01-20  Released
# 4                              Univ Of Minnesota Press   2010-02-05  Released
# 5                                        HarperCollins   1932-01-09  Released
# 6               Simon & Schuster Children's Publishing   1999-05-16  Released
# 7                            Farrar, Straus and Giroux   2002-10-11  Released
# 8                                     Feiwel & Friends   1989-06-02  Released
# 9                                      Disney-Hyperion   2003-09-03  Released
# 10                                         Forge Books   1990-02-02  Released
# 11                                    powerHouse Books   2001-12-11  Released
# 12                                          minedition   2013-09-12  Released
# 13                         Bloomsbury Children's Books   1975-05-21  Released
# 14             Macmillan (an Imprint of Pan Macmillan)   1965-06-17  Released
# 15                                            Park Row   2000-01-10  Released
# 16                                       HarperCollins   1973-03-01  Released
# 17                                        Random House   1965-06-06  Released
# 18                        NY: Linden/ Simon & Schuster   1991-05-10  Released
# 19                                       Westbow Press   2003-11-16  Released
# 20                           Houghton Mifflin Harcourt   1990-03-09  Released
# 21                                            Scribner   2014-03-11  Released
# 22                                     Anaconda Verlag   1997-04-04  Released
# 23                           Houghton Mifflin Harcourt   1956-03-06  Released
# 24                              W. W. Norton & Company   2001-01-09  Released
# 25                                        Viking Adult   1994-10-27  Released
# 26                                       HarperCollins   1974-04-01  Released
# 27                                           Doubleday   1997-11-18  Released
# 28                                           Doubleday   1993-06-30  Released
# 29                                      Parragon Books   1998-01-23  Released
# ..                                                 ...          ...       ...
# 415                                            Picador   1983-10-20  Released
# 416                                        Arrow Books   1958-10-07  Released
# 417                                              Orbit   2007-01-01  Released
# 418                                         Atom books   1998-03-06  Released
# 419                                   Simon & Schuster   1972-11-09  Released
# 420                                              Arrow   1945-10-26  Released
# 421                        University Of Chicago Press   2001-01-09  Released
# 422                       Written World Communications   1997-04-14  Released
# 423                             Quercus Publishing Plc   1998-06-26  Released
# 424                                              Ebury   2001-11-02  Released
# 425                               Sourcebooks Landmark   1987-07-24  Released
# 426                                           Arcturus   1999-11-12  Released
# 427              Little, Brown Books for Young Readers   2000-08-23  Released
# 428                                      Gallery Books   1993-05-09  Released
# 429                                   Hodder Paperback   1987-10-09  Released
# 430                                            Vintage   1998-10-16  Released
# 431                                    William Collins   1999-03-12  Released
# 432                                      Button Poetry   1996-09-13  Released
# 433            Dystel and Goderich Literary Management   1990-09-14  Released
# 434                                            Vintage   1997-09-27  Released
# 435                               Faber & Faber Poetry   1998-10-16  Released
# 436                                Rowohlt Taschenbuch   1997-03-14  Released
# 437                               NEW AMERICAN LIBRARY   1997-11-06  Released
# 438                                             Dutton   2016-02-05  Released
# 439                      Random House Trade Paperbacks   1971-11-29  Released
# 440                                      iUniverse.com   2003-04-03  Released
# 437                   The only good bug is a dead bug.           6.7  1997.0
# 438  Sometimes you have to risk everything to final...           5.8  1991.0
# 439                                                NaN           7.0  1971.0
# 440  He doesn't want money. He wants what money can...           6.0  2003.0
# 441                         The game is far from over.           6.1  2001.0
# 442                             Justice has its price.           6.1  1998.0
# 443  Health Warning: Adopting Bridget's lifestyle c...           6.6  2001.0
# 444                            Terrorâ¦ in the flesh.           5.5  2003.0
#
#                   movie title       genre1           genre2    genre3  \
# 0                          Go        Crime           Comedy  Thriller
# 1                      Faster        Crime            Drama    Action
# 2                        Girl       Comedy            Drama   Romance
# 3           Are We There Yet?    Adventure           Comedy    Family
# 4                      Frozen     Thriller
# 5                   Forbidden        Drama
# 6                       Fever        Drama         Thriller
# 7            Tuck Everlasting        Drama           Family   Fantasy
# 8                   Renegades       Action            Crime  Thriller
# 9                    Zero Day        Drama
# 10                  Flashback       Action           Comedy     Crime
# 11                        Ali        Drama
# 12             Romeo & Juliet        Drama          Romance
# 13                   Breakout       Action        Adventure  Thriller
# 14              The Collector      Mystery            Drama  Thriller
# 15               The Crossing        Drama          History       War
# 16            Charlotte's Web    Animation            Drama    Family
# 17                      Women        Drama          Romance
# 18                     Switch      Fantasy           Comedy
# 19                    Monster        Crime            Drama
# 20        The Handmaid's Tale        Drama  Science Fiction
# 21               The Outsider       Action            Crime     Drama
# 22              Anna Karenina        Drama          Romance
# 23                       1984        Drama  Science Fiction
# 24                       Jazz  Documentary
# 25              Little Odessa       Action            Drama
# 26                  Dark Star       Comedy  Science Fiction
# 27              The Rainmaker        Drama            Crime  Thriller
# 28                   The Firm        Drama          Mystery  Thriller
# 29        The Gingerbread Man     Thriller
# ..                        ...          ...              ...       ...
# 415           The Right Stuff        Drama          History
# 416   The Old Man and the Sea    Adventure            Drama
# 417                   Descent        Drama         Thriller
# 418                  Twilight        Drama            Crime   Mystery
# 419                      1776        Drama           Comedy   History
# 420              Love Letters      Romance
# 421                The Pledge        Crime            Drama   Mystery
# 422                     Bliss        Drama          Romance
# 423              Out of Sight      Romance           Comedy     Crime
# 424                   The One       Action  Science Fiction  Thriller
# 425        Wish You Were Here       Comedy            Drama   Foreign
# 426            Mansfield Park        Drama          Romance
# 427       Beautiful Creatures       Comedy            Crime     Drama
# 428         The Tommyknockers       Horror  Science Fiction
# 429  Someone to Watch Over Me        Crime            Drama   Romance
# 430                   Beloved        Drama         Thriller
# 431          Forces of Nature      Romance           Comedy
# 432                     Bound        Crime            Drama   Romance
# 433               Repossessed       Comedy           Horror
# 434                    Lolita        Drama          Romance
# 435                 Happiness       Comedy            Drama
# 436                  Insomnia        Crime            Drama  Thriller
# 437         Starship Troopers    Adventure           Action  Thriller
# 438                Wildflower     Thriller            Drama
# 439    Nicholas and Alexandra      Romance            Drama       War
# 440            The Good Thief        Crime            Drama  Thriller
# 441       Along Came a Spider        Crime          Mystery  Thriller
# 442            A Civil Action        Drama
# 443     Bridget Jones's Diary       Comedy          Romance     Drama
# 444               Cabin Fever       Horror
#
#               genre4                      id
# 0                                  80,35,53,
# 1           Thriller            80,18,28,53,
# 2              Music      35,18,10749,10402,
# 3            Romance      12,35,10751,10749,
# 4                                        53,
# 5                                        18,
# 6                                     18,53,
# 7            Romance  18,10751,14,10749,878,
# 8                                  28,80,53,
# 9                                        18,
# 10                                 28,35,80,
# 11                                       18,
# 12                                 18,10749,
# 13                                 28,12,53,
# 14                               9648,18,53,
# 15                              18,36,10752,
# 16                              16,18,10751,
# 17                                 18,10749,
# 18                                    14,35,
# 19                                    80,18,
# 20                                   18,878,
# 21           Mystery       28,80,18,9648,53,
# 22                                 18,10749,
# 23                                   18,878,
# 24                                       99,
# 25                                    28,18,
# 26                                   35,878,
# 27                                 18,80,53,
# 28                               18,9648,53,
# 29                                       53,
# ..               ...                     ...
# 415                                   18,36,
# 416                                   12,18,
# 417                                   18,53,
# 418         Thriller          18,80,9648,53,
# 419            Music         18,35,36,10402,
# 420                                   10749,
# 421         Thriller          80,18,9648,53,
# 422                                18,10749,
# 423                             10749,35,80,
# 424                               28,878,53,
# 425          Romance      35,18,10769,10749,
# 426                                18,10749,
# 427         Thriller            35,80,18,53,
# 428                                  27,878,
# 429         Thriller         80,18,10749,53,
# 430                                   18,53,
# 431                                10749,35,
# 432         Thriller         80,18,10749,53,
# 433                                   35,27,
# 434                                18,10749,
# 435                                   35,18,
# 436                                80,18,53,
# 437  Science Fiction           12,28,53,878,
# 438                                   53,18,
# 439                          10749,18,10752,
# 440                                80,18,53,
# 441           Action          80,9648,53,28,
# 442                                      18,
# 443                             35,10749,18,
# 444                                      27,
#
# [445 rows x 17 columns]

# %%
#Write file to CSV
final_df.to_csv('master_data.csv')

# %% [markdown]
# ####TEST CRAP####

# %%
#Set double column index by book and movie title
#final_df_2 = final_df.set_index(['book title','movie title'])
#final_df_2

# %%
#hello = genre_df.genres[0]
#b = hello.replace("'",'"')
#jdata2 = json.loads(b)

# %%
#jdata2

# %%
#Dummy DF
#d = {'id': [], 'name': [], 'title': []}
#d = ashley
#df_genre = pd.DataFrame(data=d)
#df_genre

# %%
#for item in genre_df.genres:
    #dataItem = json.loads(item.replace("'",'"'))
    #df_genre = pd.DataFrame(data=dataItem)
    #print (df_genre)

# %%
#def

#s = set()
#x = set()
#for value in genre_df.genres:
#    s = value
#    print (s)
#    tempVar = s.split("},")
#    print (tempVar)
#    for value2 in s:
#        x = value2
#        print(x)
   
    #print (x)
    #tempStr = value.replace("[","").replace("]","").replace("{","").replace("}","-").replace(" ","").replace("'","")
    #tempStr2 = tempStr.split("-")
    
    #print (tempStr2)

    
#for index in range(len(genre_df.genres)):
    #print (genre_df.genres[index])
    #print (genre_df.genres[index]["id"])
    #print (genre_df.title[index])
    
#hello = genre_df.genres[0]
#b = hello.replace("'",'"')
#jdata2 = json.loads(b)

# %%
#(merged_df_2.genres[0])

# %%
#(genre_df.title[0])

# %%
    #print (df_genre) 
    #print (genre_df.title[index])
    #d= df_genre
    #df_genre2 = pd.DataFrame(data=d)
    #print (df_genre)
